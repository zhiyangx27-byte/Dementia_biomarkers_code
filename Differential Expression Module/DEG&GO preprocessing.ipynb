# %% [markdown]
# # DEGs and GO analysis preprocessing

# %% [markdown]
# In order to deal with the data in R, we need to preprocess the original data.

# %%
import os
import pandas as pd
import scipy.sparse as sp
import scanpy as sc
from scipy.io import mmwrite

# %%
subclasses = ["L2/3 IT", "L4 IT", "L5 IT", "Vip", "Oligodendrocyte"]

# %%
DONOR_ID_COLUMN = 'Donor ID' 
COVARIATES = ['Age at Death', 'Sex', 'PMI'] 
REQUIRED_COLS = ['Cognitive Status', DONOR_ID_COLUMN] + COVARIATES

# %%
def process_data(name):
    safe_name = name.replace('/', '_')
    # Please change the path to your own!
    input_dir = '/Users/a1234/Desktop/Omics data (scRNA-seq)'
    output_dir = f'/Users/a1234/Desktop/Processed_{safe_name}'
    os.makedirs(output_dir, exist_ok=True)

    all_obs = []
    all_X = []
    gene_names = None
    file_counter = 0

    sampling_params = {
        'max_cells_per_file': 500,
        'fraction_threshold': 0.5,
        'min_cells_after_sampling': 10,
        'random_seed': 42
    }

    unique_gene_df = None

    for root, dirs, files in os.walk(input_dir):
        for file in files:
            if not file.endswith('.h5ad'):
                continue

            file_path = os.path.join(root, file)
            file_counter += 1
            print(f"Processing file #{file_counter}: {file}")

            try:
                adata = sc.read_h5ad(file_path)
                name_mask = adata.obs["Subclass"] == f"{name}"
                name_data = adata[name_mask].copy()

                if name_data.n_obs == 0:
                    print(f"File {file} has 0 {name} cells, skip it.")
                    continue

                original_cell_count = name_data.n_obs

                # Sampling Process
                if original_cell_count > sampling_params['max_cells_per_file']:
                    sc.pp.subsample(
                        name_data,
                        n_obs=sampling_params['max_cells_per_file'],
                        random_state=sampling_params['random_seed']
                    )
                elif original_cell_count > 1 / sampling_params['fraction_threshold']:
                    sc.pp.subsample(
                        name_data,
                        fraction=sampling_params['fraction_threshold'],
                        random_state=sampling_params['random_seed']
                    )
                else:
                    print(f"({original_cell_count} cells) remain the original format.")

                if name_data.n_obs < sampling_params['min_cells_after_sampling']:
                    print(f"{name_data.n_obs} cells are not enough after sampling, skip it.")
                    continue

                # Cell ID Enhancement
                if DONOR_ID_COLUMN not in name_data.obs.columns:
                    raise KeyError(f"Lack the core column: {DONOR_ID_COLUMN}")

                donor_ids = name_data.obs[DONOR_ID_COLUMN].tolist()

                new_index = [
                    f"{donor_id}_{idx}_s{original_cell_count}a{name_data.n_obs}"
                    for donor_id, idx in zip(donor_ids, name_data.obs.index)
                ]

                name_data.obs.index = new_index
                name_data.obs.index.name = "cell_id"

                if not sp.issparse(name_data.X):
                    name_data.X = sp.csr_matrix(name_data.X)
                else:
                    name_data.X = name_data.X.tocsr()

                # Gene deduplication
                if gene_names is None:
                    if 'gene_id' in name_data.var.columns and 'gene_name' in name_data.var.columns:
                        gene_ids = name_data.var['gene_id'].tolist()
                        gene_symbols = name_data.var['gene_name'].tolist()
                    elif name_data.var.index.name == 'gene_id' and 'gene_name' in name_data.var.columns:
                        gene_ids = name_data.var.index.tolist()
                        gene_symbols = name_data.var['gene_name'].tolist()
                    else:
                        gene_ids = name_data.var.index.tolist()
                        gene_symbols = name_data.var.index.tolist()
                        print("Warning: use var.index as gene_id and gene_name")

                    gene_df = pd.DataFrame({'gene_id': gene_ids, 'gene_name': gene_symbols})
                    unique_gene_df = gene_df.drop_duplicates(subset=['gene_id'], keep='first')

                    original_gene_count = len(gene_df)
                    final_gene_count = len(unique_gene_df)
                    print(
                        f"Gene deduplication: Origin {original_gene_count} genes; After deduplication {final_gene_count} genes")

                    gene_names = list(zip(unique_gene_df['gene_id'], unique_gene_df['gene_name']))

                name_data = name_data[:, unique_gene_df.index.tolist()]

                # Collect all related metadata 
                required_metadata = name_data.obs[REQUIRED_COLS].copy()

                all_obs.append(required_metadata)
                all_X.append(name_data.X)

                print(f"Successfully deal with {file}: {original_cell_count} -> {name_data.n_obs} for {name} cells")

            except Exception as e:
                print(f"When dealing with {file}, we face an ERROR: {str(e)}")
                continue

        if all_obs and all_X:
            print("\nStart merging...")

            try:
                combined_obs = pd.concat(all_obs, axis=0, verify_integrity=True)
            except ValueError as e:
                print("\n[CRITICAL ERROR] Data merge failed due to overlapping Cell IDs.")
                print("Please check whether the 'Donor ID' has been correctly incorporated into the 'Cell ID' generation logic.")
                raise e  

            combined_X = sp.vstack(all_X, format='csr').T

            print("Saving the results...")

            combined_obs[REQUIRED_COLS].to_csv(
                os.path.join(output_dir, 'metadata.csv'),
                index=True, index_label="cell_id"
            )
            
            # Save the Data

            mmwrite(os.path.join(output_dir, 'matrix.mtx'), combined_X)

            pd.Series(combined_obs.index).to_csv(
                os.path.join(output_dir, 'barcodes.tsv'),
                index=False, header=False
            )

            pd.DataFrame(gene_names, columns=['gene_id', 'gene_name']).to_csv(
                os.path.join(output_dir, 'genes.tsv'),
                sep='\t',
                index=False,
                header=False
            )

            print(f"ALL DONE! Final dimensions of data: {combined_X.shape} (genes x cells)")

# %%
if __name__ == '__main__':
    for name in subclasses:
        process_data(name)
# Out:
# Processing file #1: H21.33.028_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Warning: use var.index as gene_id and gene_name
# Gene deduplication: Origin 36601 genes; After deduplication 36601 genes
# Successfully deal with H21.33.028_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 3657 -> 500 for L2/3 IT cells
# Processing file #2: H21.33.007_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.007_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 3089 -> 500 for L2/3 IT cells
# Processing file #3: H20.33.001_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.001_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 5394 -> 500 for L2/3 IT cells
# Processing file #4: H20.33.035_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.035_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2483 -> 500 for L2/3 IT cells
# Processing file #5: H21.33.041_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.041_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 3301 -> 500 for L2/3 IT cells
# Processing file #6: H21.33.010_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.010_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2950 -> 500 for L2/3 IT cells
# Processing file #7: H20.33.016_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.016_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 5132 -> 500 for L2/3 IT cells
# Processing file #8: H21.33.033_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.033_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 944 -> 500 for L2/3 IT cells
# Processing file #9: H20.33.039_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.039_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 5388 -> 500 for L2/3 IT cells
# Processing file #10: H21.33.006_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.006_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 6731 -> 500 for L2/3 IT cells
# Processing file #11: H21.33.029_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.029_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1862 -> 500 for L2/3 IT cells
# Processing file #12: H21.33.025_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.025_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2344 -> 500 for L2/3 IT cells
# Processing file #13: H21.33.011_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.011_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 6555 -> 500 for L2/3 IT cells
# Processing file #14: H20.33.034_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.034_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 4564 -> 500 for L2/3 IT cells
# Processing file #15: H21.33.040_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.040_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2953 -> 500 for L2/3 IT cells
# Processing file #16: H20.33.038_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.038_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 201 -> 100 for L2/3 IT cells
# Processing file #17: H21.33.032_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.032_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 4705 -> 500 for L2/3 IT cells
# Processing file #18: H20.33.046_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.046_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 3698 -> 500 for L2/3 IT cells
# Processing file #19: H20.33.017_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.017_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2464 -> 500 for L2/3 IT cells
# Processing file #20: H21.33.009_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.009_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 879 -> 500 for L2/3 IT cells
# Processing file #21: H21.33.026_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.026_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2507 -> 500 for L2/3 IT cells
# Processing file #22: H20.33.020_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.020_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 3596 -> 500 for L2/3 IT cells
# Processing file #23: H21.33.005_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.005_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2585 -> 500 for L2/3 IT cells
# Processing file #24: H200.1023_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H200.1023_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 367 -> 183 for L2/3 IT cells
# Processing file #25: H20.33.014_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.014_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 6409 -> 500 for L2/3 IT cells
# Processing file #26: H21.33.031_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.031_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 4368 -> 500 for L2/3 IT cells
# Processing file #27: H20.33.045_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.045_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 613 -> 500 for L2/3 IT cells
# Processing file #28: H20.33.037_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.037_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 804 -> 500 for L2/3 IT cells
# Processing file #29: H21.33.043_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.043_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 3665 -> 500 for L2/3 IT cells
# Processing file #30: H20.33.018_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.018_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 3718 -> 500 for L2/3 IT cells
# Processing file #31: H21.33.012_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.012_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 3416 -> 500 for L2/3 IT cells
# Processing file #32: H21.33.027_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.027_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 10628 -> 500 for L2/3 IT cells
# Processing file #33: H21.33.008_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.008_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2372 -> 500 for L2/3 IT cells
# Processing file #34: H20.33.002_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.002_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 6729 -> 500 for L2/3 IT cells
# Processing file #35: H21.33.004_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.004_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 3937 -> 500 for L2/3 IT cells
# Processing file #36: H21.33.030_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.030_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 3271 -> 500 for L2/3 IT cells
# Processing file #37: H20.33.044_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.044_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 4218 -> 500 for L2/3 IT cells
# Processing file #38: H20.33.015_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.015_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 5223 -> 500 for L2/3 IT cells
# Processing file #39: H21.33.013_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.013_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1731 -> 500 for L2/3 IT cells
# Processing file #40: H20.33.019_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.019_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 5234 -> 500 for L2/3 IT cells
# Processing file #41: H20.33.036_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.036_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 821 -> 500 for L2/3 IT cells
# Processing file #42: H21.33.042_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.042_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 3534 -> 500 for L2/3 IT cells
# Processing file #43: H21.33.014_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.014_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 3774 -> 500 for L2/3 IT cells
# Processing file #44: H20.33.031_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.031_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 3420 -> 500 for L2/3 IT cells
# Processing file #45: H21.33.045_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.045_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 936 -> 500 for L2/3 IT cells
# Processing file #46: H21.33.037_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.037_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2270 -> 500 for L2/3 IT cells
# Processing file #47: H20.33.043_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.043_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 5851 -> 500 for L2/3 IT cells
# Processing file #48: H21.33.018_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.018_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 3175 -> 500 for L2/3 IT cells
# Processing file #49: H20.33.012_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.012_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 4543 -> 500 for L2/3 IT cells
# Processing file #50: H21.33.003_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.003_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 4839 -> 500 for L2/3 IT cells
# Processing file #51: H21.33.020_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.020_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 71 -> 35 for L2/3 IT cells
# Processing file #52: H20.33.005_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.005_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 5269 -> 500 for L2/3 IT cells
# Processing file #53: H20.33.030_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.030_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 5934 -> 500 for L2/3 IT cells
# Processing file #54: H21.33.044_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.044_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1337 -> 500 for L2/3 IT cells
# Processing file #55: H21.33.015_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.015_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 4873 -> 500 for L2/3 IT cells
# Processing file #56: H20.33.013_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.013_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 6732 -> 500 for L2/3 IT cells
# Processing file #57: H21.33.019_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.019_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 7089 -> 500 for L2/3 IT cells
# Processing file #58: H21.33.036_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.036_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2808 -> 500 for L2/3 IT cells
# Processing file #59: H20.33.027_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.027_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 6289 -> 500 for L2/3 IT cells
# Processing file #60: H20.33.008_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.008_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 3519 -> 500 for L2/3 IT cells
# Processing file #61: H21.33.002_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.002_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 3909 -> 500 for L2/3 IT cells
# Processing file #62: H20.33.004_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.004_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 5865 -> 500 for L2/3 IT cells
# Processing file #63: H21.33.021_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.021_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1376 -> 500 for L2/3 IT cells
# Processing file #64: H21.33.035_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.035_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 3493 -> 500 for L2/3 IT cells
# Processing file #65: H20.33.041_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.041_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 3548 -> 500 for L2/3 IT cells
# Processing file #66: H21.33.016_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.016_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2565 -> 500 for L2/3 IT cells
# Processing file #67: H20.33.033_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.033_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1074 -> 500 for L2/3 IT cells
# Processing file #68: H21.33.047_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.047_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 3315 -> 500 for L2/3 IT cells
# Processing file #69: H21.33.039_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.039_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1853 -> 500 for L2/3 IT cells
# Processing file #70: H20.33.028_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.028_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 938 -> 500 for L2/3 IT cells
# Processing file #71: H21.33.022_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.022_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 3829 -> 500 for L2/3 IT cells
# Processing file #72: H19.33.004_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H19.33.004_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 6428 -> 500 for L2/3 IT cells
# Processing file #73: H21.33.001_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.001_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 3473 -> 500 for L2/3 IT cells
# Processing file #74: H20.33.024_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.024_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 3219 -> 500 for L2/3 IT cells
# Processing file #75: H20.33.011_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.011_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 5061 -> 500 for L2/3 IT cells
# Processing file #76: H21.33.034_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.034_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 775 -> 500 for L2/3 IT cells
# Processing file #77: H20.33.040_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.040_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2824 -> 500 for L2/3 IT cells
# Processing file #78: H21.33.038_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.038_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1522 -> 500 for L2/3 IT cells
# Processing file #79: H20.33.032_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.032_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 3298 -> 500 for L2/3 IT cells
# Processing file #80: H21.33.046_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.046_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1409 -> 500 for L2/3 IT cells
# Processing file #81: H21.33.017_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.017_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2370 -> 500 for L2/3 IT cells
# Processing file #82: H21.33.023_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.023_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 5407 -> 500 for L2/3 IT cells
# Processing file #83: H20.33.029_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.029_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 3206 -> 500 for L2/3 IT cells
# Processing file #84: H20.33.025_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.025_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 7981 -> 500 for L2/3 IT cells
#
# Start merging...
# Saving the results...
# ALL DONE! Final dimensions of data: (36601, 40818) (genes x cells)
# Processing file #1: H21.33.028_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Warning: use var.index as gene_id and gene_name
# Gene deduplication: Origin 36601 genes; After deduplication 36601 genes
# Successfully deal with H21.33.028_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1299 -> 500 for L4 IT cells
# Processing file #2: H21.33.007_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.007_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2104 -> 500 for L4 IT cells
# Processing file #3: H20.33.001_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.001_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2525 -> 500 for L4 IT cells
# Processing file #4: H20.33.035_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.035_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 904 -> 500 for L4 IT cells
# Processing file #5: H21.33.041_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.041_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1745 -> 500 for L4 IT cells
# Processing file #6: H21.33.010_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.010_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2796 -> 500 for L4 IT cells
# Processing file #7: H20.33.016_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.016_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2485 -> 500 for L4 IT cells
# Processing file #8: H21.33.033_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.033_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 627 -> 500 for L4 IT cells
# Processing file #9: H20.33.039_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.039_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 3212 -> 500 for L4 IT cells
# Processing file #10: H21.33.006_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.006_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2363 -> 500 for L4 IT cells
# Processing file #11: H21.33.029_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.029_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 915 -> 500 for L4 IT cells
# Processing file #12: H21.33.025_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.025_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1599 -> 500 for L4 IT cells
# Processing file #13: H21.33.011_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.011_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1742 -> 500 for L4 IT cells
# Processing file #14: H20.33.034_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.034_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1927 -> 500 for L4 IT cells
# Processing file #15: H21.33.040_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.040_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2184 -> 500 for L4 IT cells
# Processing file #16: H20.33.038_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.038_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 413 -> 206 for L4 IT cells
# Processing file #17: H21.33.032_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.032_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1390 -> 500 for L4 IT cells
# Processing file #18: H20.33.046_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.046_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2124 -> 500 for L4 IT cells
# Processing file #19: H20.33.017_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.017_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2604 -> 500 for L4 IT cells
# Processing file #20: H21.33.009_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.009_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2461 -> 500 for L4 IT cells
# Processing file #21: H21.33.026_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.026_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1636 -> 500 for L4 IT cells
# Processing file #22: H20.33.020_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.020_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2754 -> 500 for L4 IT cells
# Processing file #23: H21.33.005_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.005_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2388 -> 500 for L4 IT cells
# Processing file #24: H200.1023_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H200.1023_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1300 -> 500 for L4 IT cells
# Processing file #25: H20.33.014_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.014_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2142 -> 500 for L4 IT cells
# Processing file #26: H21.33.031_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.031_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1408 -> 500 for L4 IT cells
# Processing file #27: H20.33.045_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.045_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1411 -> 500 for L4 IT cells
# Processing file #28: H20.33.037_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.037_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 937 -> 500 for L4 IT cells
# Processing file #29: H21.33.043_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.043_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1459 -> 500 for L4 IT cells
# Processing file #30: H20.33.018_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.018_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 3309 -> 500 for L4 IT cells
# Processing file #31: H21.33.012_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.012_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1988 -> 500 for L4 IT cells
# Processing file #32: H21.33.027_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.027_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2515 -> 500 for L4 IT cells
# Processing file #33: H21.33.008_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.008_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 3645 -> 500 for L4 IT cells
# Processing file #34: H20.33.002_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.002_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2173 -> 500 for L4 IT cells
# Processing file #35: H21.33.004_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.004_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1747 -> 500 for L4 IT cells
# Processing file #36: H21.33.030_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.030_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1304 -> 500 for L4 IT cells
# Processing file #37: H20.33.044_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.044_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1492 -> 500 for L4 IT cells
# Processing file #38: H20.33.015_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.015_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2185 -> 500 for L4 IT cells
# Processing file #39: H21.33.013_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.013_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2124 -> 500 for L4 IT cells
# Processing file #40: H20.33.019_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.019_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2432 -> 500 for L4 IT cells
# Processing file #41: H20.33.036_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.036_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1630 -> 500 for L4 IT cells
# Processing file #42: H21.33.042_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.042_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1631 -> 500 for L4 IT cells
# Processing file #43: H21.33.014_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.014_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1620 -> 500 for L4 IT cells
# Processing file #44: H20.33.031_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.031_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1434 -> 500 for L4 IT cells
# Processing file #45: H21.33.045_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.045_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1189 -> 500 for L4 IT cells
# Processing file #46: H21.33.037_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.037_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 613 -> 500 for L4 IT cells
# Processing file #47: H20.33.043_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.043_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2662 -> 500 for L4 IT cells
# Processing file #48: H21.33.018_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.018_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1455 -> 500 for L4 IT cells
# Processing file #49: H20.33.012_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.012_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2438 -> 500 for L4 IT cells
# Processing file #50: H21.33.003_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.003_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1766 -> 500 for L4 IT cells
# Processing file #51: H21.33.020_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.020_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 144 -> 72 for L4 IT cells
# Processing file #52: H20.33.005_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.005_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 4728 -> 500 for L4 IT cells
# Processing file #53: H20.33.030_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.030_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2633 -> 500 for L4 IT cells
# Processing file #54: H21.33.044_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.044_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 932 -> 500 for L4 IT cells
# Processing file #55: H21.33.015_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.015_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1636 -> 500 for L4 IT cells
# Processing file #56: H20.33.013_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.013_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1624 -> 500 for L4 IT cells
# Processing file #57: H21.33.019_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.019_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2598 -> 500 for L4 IT cells
# Processing file #58: H21.33.036_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.036_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1053 -> 500 for L4 IT cells
# Processing file #59: H20.33.027_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.027_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1651 -> 500 for L4 IT cells
# Processing file #60: H20.33.008_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.008_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1867 -> 500 for L4 IT cells
# Processing file #61: H21.33.002_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.002_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1382 -> 500 for L4 IT cells
# Processing file #62: H20.33.004_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.004_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2660 -> 500 for L4 IT cells
# Processing file #63: H21.33.021_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.021_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2674 -> 500 for L4 IT cells
# Processing file #64: H21.33.035_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.035_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1888 -> 500 for L4 IT cells
# Processing file #65: H20.33.041_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.041_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2131 -> 500 for L4 IT cells
# Processing file #66: H21.33.016_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.016_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1314 -> 500 for L4 IT cells
# Processing file #67: H20.33.033_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.033_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 641 -> 500 for L4 IT cells
# Processing file #68: H21.33.047_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.047_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1292 -> 500 for L4 IT cells
# Processing file #69: H21.33.039_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.039_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1487 -> 500 for L4 IT cells
# Processing file #70: H20.33.028_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.028_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1599 -> 500 for L4 IT cells
# Processing file #71: H21.33.022_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.022_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2358 -> 500 for L4 IT cells
# Processing file #72: H19.33.004_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H19.33.004_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 3420 -> 500 for L4 IT cells
# Processing file #73: H21.33.001_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.001_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2457 -> 500 for L4 IT cells
# Processing file #74: H20.33.024_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.024_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1544 -> 500 for L4 IT cells
# Processing file #75: H20.33.011_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.011_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1673 -> 500 for L4 IT cells
# Processing file #76: H21.33.034_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.034_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 172 -> 86 for L4 IT cells
# Processing file #77: H20.33.040_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.040_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1636 -> 500 for L4 IT cells
# Processing file #78: H21.33.038_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.038_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 929 -> 500 for L4 IT cells
# Processing file #79: H20.33.032_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.032_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1607 -> 500 for L4 IT cells
# Processing file #80: H21.33.046_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.046_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 776 -> 500 for L4 IT cells
# Processing file #81: H21.33.017_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.017_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 590 -> 500 for L4 IT cells
# Processing file #82: H21.33.023_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.023_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1545 -> 500 for L4 IT cells
# Processing file #83: H20.33.029_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.029_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1505 -> 500 for L4 IT cells
# Processing file #84: H20.33.025_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.025_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2270 -> 500 for L4 IT cells
#
# Start merging...
# Saving the results...
# ALL DONE! Final dimensions of data: (36601, 40864) (genes x cells)
# Processing file #1: H21.33.028_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Warning: use var.index as gene_id and gene_name
# Gene deduplication: Origin 36601 genes; After deduplication 36601 genes
# Successfully deal with H21.33.028_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 915 -> 500 for L5 IT cells
# Processing file #2: H21.33.007_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.007_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1078 -> 500 for L5 IT cells
# Processing file #3: H20.33.001_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.001_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1885 -> 500 for L5 IT cells
# Processing file #4: H20.33.035_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.035_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 631 -> 500 for L5 IT cells
# Processing file #5: H21.33.041_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.041_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1616 -> 500 for L5 IT cells
# Processing file #6: H21.33.010_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.010_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1726 -> 500 for L5 IT cells
# Processing file #7: H20.33.016_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.016_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1846 -> 500 for L5 IT cells
# Processing file #8: H21.33.033_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.033_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 432 -> 216 for L5 IT cells
# Processing file #9: H20.33.039_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.039_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 3050 -> 500 for L5 IT cells
# Processing file #10: H21.33.006_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.006_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1715 -> 500 for L5 IT cells
# Processing file #11: H21.33.029_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.029_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1155 -> 500 for L5 IT cells
# Processing file #12: H21.33.025_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.025_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1256 -> 500 for L5 IT cells
# Processing file #13: H21.33.011_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.011_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1330 -> 500 for L5 IT cells
# Processing file #14: H20.33.034_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.034_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1333 -> 500 for L5 IT cells
# Processing file #15: H21.33.040_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.040_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1547 -> 500 for L5 IT cells
# Processing file #16: H20.33.038_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.038_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 55 -> 27 for L5 IT cells
# Processing file #17: H21.33.032_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.032_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1234 -> 500 for L5 IT cells
# Processing file #18: H20.33.046_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.046_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1545 -> 500 for L5 IT cells
# Processing file #19: H20.33.017_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.017_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1623 -> 500 for L5 IT cells
# Processing file #20: H21.33.009_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.009_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1161 -> 500 for L5 IT cells
# Processing file #21: H21.33.026_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.026_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 959 -> 500 for L5 IT cells
# Processing file #22: H20.33.020_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.020_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1981 -> 500 for L5 IT cells
# Processing file #23: H21.33.005_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.005_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1833 -> 500 for L5 IT cells
# Processing file #24: H200.1023_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H200.1023_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1556 -> 500 for L5 IT cells
# Processing file #25: H20.33.014_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.014_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2092 -> 500 for L5 IT cells
# Processing file #26: H21.33.031_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.031_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1208 -> 500 for L5 IT cells
# Processing file #27: H20.33.045_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.045_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 488 -> 244 for L5 IT cells
# Processing file #28: H20.33.037_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.037_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 641 -> 500 for L5 IT cells
# Processing file #29: H21.33.043_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.043_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1138 -> 500 for L5 IT cells
# Processing file #30: H20.33.018_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.018_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2307 -> 500 for L5 IT cells
# Processing file #31: H21.33.012_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.012_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1459 -> 500 for L5 IT cells
# Processing file #32: H21.33.027_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.027_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1392 -> 500 for L5 IT cells
# Processing file #33: H21.33.008_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.008_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1537 -> 500 for L5 IT cells
# Processing file #34: H20.33.002_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.002_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1857 -> 500 for L5 IT cells
# Processing file #35: H21.33.004_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.004_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1459 -> 500 for L5 IT cells
# Processing file #36: H21.33.030_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.030_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 838 -> 500 for L5 IT cells
# Processing file #37: H20.33.044_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.044_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1376 -> 500 for L5 IT cells
# Processing file #38: H20.33.015_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.015_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1914 -> 500 for L5 IT cells
# Processing file #39: H21.33.013_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.013_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1308 -> 500 for L5 IT cells
# Processing file #40: H20.33.019_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.019_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2136 -> 500 for L5 IT cells
# Processing file #41: H20.33.036_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.036_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 473 -> 236 for L5 IT cells
# Processing file #42: H21.33.042_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.042_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1385 -> 500 for L5 IT cells
# Processing file #43: H21.33.014_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.014_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1111 -> 500 for L5 IT cells
# Processing file #44: H20.33.031_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.031_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1122 -> 500 for L5 IT cells
# Processing file #45: H21.33.045_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.045_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 816 -> 500 for L5 IT cells
# Processing file #46: H21.33.037_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.037_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 639 -> 500 for L5 IT cells
# Processing file #47: H20.33.043_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.043_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2159 -> 500 for L5 IT cells
# Processing file #48: H21.33.018_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.018_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1018 -> 500 for L5 IT cells
# Processing file #49: H20.33.012_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.012_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1812 -> 500 for L5 IT cells
# Processing file #50: H21.33.003_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.003_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1653 -> 500 for L5 IT cells
# Processing file #51: H21.33.020_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# 6 cells are not enough after sampling, skip it.
# Processing file #52: H20.33.005_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.005_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 3318 -> 500 for L5 IT cells
# Processing file #53: H20.33.030_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.030_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1784 -> 500 for L5 IT cells
# Processing file #54: H21.33.044_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.044_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 447 -> 223 for L5 IT cells
# Processing file #55: H21.33.015_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.015_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1265 -> 500 for L5 IT cells
# Processing file #56: H20.33.013_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.013_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1336 -> 500 for L5 IT cells
# Processing file #57: H21.33.019_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.019_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2153 -> 500 for L5 IT cells
# Processing file #58: H21.33.036_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.036_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1157 -> 500 for L5 IT cells
# Processing file #59: H20.33.027_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.027_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1454 -> 500 for L5 IT cells
# Processing file #60: H20.33.008_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.008_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1198 -> 500 for L5 IT cells
# Processing file #61: H21.33.002_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.002_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 817 -> 500 for L5 IT cells
# Processing file #62: H20.33.004_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.004_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1943 -> 500 for L5 IT cells
# Processing file #63: H21.33.021_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.021_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 771 -> 500 for L5 IT cells
# Processing file #64: H21.33.035_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.035_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1444 -> 500 for L5 IT cells
# Processing file #65: H20.33.041_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.041_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1570 -> 500 for L5 IT cells
# Processing file #66: H21.33.016_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.016_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1114 -> 500 for L5 IT cells
# Processing file #67: H20.33.033_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.033_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 272 -> 136 for L5 IT cells
# Processing file #68: H21.33.047_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.047_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 904 -> 500 for L5 IT cells
# Processing file #69: H21.33.039_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.039_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 913 -> 500 for L5 IT cells
# Processing file #70: H20.33.028_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.028_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 364 -> 182 for L5 IT cells
# Processing file #71: H21.33.022_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.022_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1271 -> 500 for L5 IT cells
# Processing file #72: H19.33.004_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H19.33.004_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2463 -> 500 for L5 IT cells
# Processing file #73: H21.33.001_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.001_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1527 -> 500 for L5 IT cells
# Processing file #74: H20.33.024_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.024_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1291 -> 500 for L5 IT cells
# Processing file #75: H20.33.011_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.011_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1277 -> 500 for L5 IT cells
# Processing file #76: H21.33.034_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.034_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 204 -> 102 for L5 IT cells
# Processing file #77: H20.33.040_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.040_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1042 -> 500 for L5 IT cells
# Processing file #78: H21.33.038_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.038_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 512 -> 500 for L5 IT cells
# Processing file #79: H20.33.032_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.032_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1304 -> 500 for L5 IT cells
# Processing file #80: H21.33.046_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.046_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 376 -> 188 for L5 IT cells
# Processing file #81: H21.33.017_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.017_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 685 -> 500 for L5 IT cells
# Processing file #82: H21.33.023_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.023_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1321 -> 500 for L5 IT cells
# Processing file #83: H20.33.029_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.029_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 963 -> 500 for L5 IT cells
# Processing file #84: H20.33.025_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.025_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2192 -> 500 for L5 IT cells
#
# Start merging...
# Saving the results...
# ALL DONE! Final dimensions of data: (36601, 38554) (genes x cells)
# Processing file #1: H21.33.028_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Warning: use var.index as gene_id and gene_name
# ...
# Successfully deal with H20.33.001_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 582 -> 500 for Oligodendrocyte cells
# Processing file #4: H20.33.035_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.035_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1181 -> 500 for Oligodendrocyte cells
# Processing file #5: H21.33.041_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.041_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1633 -> 500 for Oligodendrocyte cells
# Processing file #6: H21.33.010_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.010_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 719 -> 500 for Oligodendrocyte cells
# Processing file #7: H20.33.016_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.016_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1819 -> 500 for Oligodendrocyte cells
# Processing file #8: H21.33.033_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.033_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 305 -> 152 for Oligodendrocyte cells
# Processing file #9: H20.33.039_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.039_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2064 -> 500 for Oligodendrocyte cells
# Processing file #10: H21.33.006_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.006_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2557 -> 500 for Oligodendrocyte cells
# Processing file #11: H21.33.029_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.029_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 858 -> 500 for Oligodendrocyte cells
# Processing file #12: H21.33.025_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.025_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 921 -> 500 for Oligodendrocyte cells
# Processing file #13: H21.33.011_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.011_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2155 -> 500 for Oligodendrocyte cells
# Processing file #14: H20.33.034_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.034_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2415 -> 500 for Oligodendrocyte cells
# Processing file #15: H21.33.040_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.040_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1432 -> 500 for Oligodendrocyte cells
# Processing file #16: H20.33.038_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.038_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 117 -> 58 for Oligodendrocyte cells
# Processing file #17: H21.33.032_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.032_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1869 -> 500 for Oligodendrocyte cells
# Processing file #18: H20.33.046_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.046_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 468 -> 234 for Oligodendrocyte cells
# Processing file #19: H20.33.017_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.017_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 919 -> 500 for Oligodendrocyte cells
# Processing file #20: H21.33.009_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.009_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1773 -> 500 for Oligodendrocyte cells
# Processing file #21: H21.33.026_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.026_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 986 -> 500 for Oligodendrocyte cells
# Processing file #22: H20.33.020_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.020_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1408 -> 500 for Oligodendrocyte cells
# Processing file #23: H21.33.005_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.005_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 708 -> 500 for Oligodendrocyte cells
# Processing file #24: H200.1023_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# 3 cells are not enough after sampling, skip it.
# Processing file #25: H20.33.014_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.014_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2308 -> 500 for Oligodendrocyte cells
# Processing file #26: H21.33.031_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.031_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 866 -> 500 for Oligodendrocyte cells
# Processing file #27: H20.33.045_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.045_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 849 -> 500 for Oligodendrocyte cells
# Processing file #28: H20.33.037_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.037_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 602 -> 500 for Oligodendrocyte cells
# Processing file #29: H21.33.043_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.043_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 918 -> 500 for Oligodendrocyte cells
# Processing file #30: H20.33.018_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.018_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2093 -> 500 for Oligodendrocyte cells
# Processing file #31: H21.33.012_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.012_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 3242 -> 500 for Oligodendrocyte cells
# Processing file #32: H21.33.027_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.027_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1428 -> 500 for Oligodendrocyte cells
# Processing file #33: H21.33.008_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.008_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2745 -> 500 for Oligodendrocyte cells
# Processing file #34: H20.33.002_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.002_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1869 -> 500 for Oligodendrocyte cells
# Processing file #35: H21.33.004_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.004_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1586 -> 500 for Oligodendrocyte cells
# Processing file #36: H21.33.030_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.030_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 764 -> 500 for Oligodendrocyte cells
# Processing file #37: H20.33.044_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.044_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1683 -> 500 for Oligodendrocyte cells
# Processing file #38: H20.33.015_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.015_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 608 -> 500 for Oligodendrocyte cells
# Processing file #39: H21.33.013_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.013_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 526 -> 500 for Oligodendrocyte cells
# Processing file #40: H20.33.019_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.019_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1119 -> 500 for Oligodendrocyte cells
# Processing file #41: H20.33.036_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.036_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 544 -> 500 for Oligodendrocyte cells
# Processing file #42: H21.33.042_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.042_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2000 -> 500 for Oligodendrocyte cells
# Processing file #43: H21.33.014_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.014_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1006 -> 500 for Oligodendrocyte cells
# Processing file #44: H20.33.031_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.031_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1316 -> 500 for Oligodendrocyte cells
# Processing file #45: H21.33.045_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.045_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 192 -> 96 for Oligodendrocyte cells
# Processing file #46: H21.33.037_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.037_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 726 -> 500 for Oligodendrocyte cells
# Processing file #47: H20.33.043_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.043_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 4423 -> 500 for Oligodendrocyte cells
# Processing file #48: H21.33.018_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.018_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1344 -> 500 for Oligodendrocyte cells
# Processing file #49: H20.33.012_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.012_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 589 -> 500 for Oligodendrocyte cells
# Processing file #50: H21.33.003_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.003_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1422 -> 500 for Oligodendrocyte cells
# Processing file #51: H21.33.020_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# 7 cells are not enough after sampling, skip it.
# Processing file #52: H20.33.005_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.005_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 591 -> 500 for Oligodendrocyte cells
# Processing file #53: H20.33.030_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.030_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2842 -> 500 for Oligodendrocyte cells
# Processing file #54: H21.33.044_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.044_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 79 -> 39 for Oligodendrocyte cells
# Processing file #55: H21.33.015_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.015_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2937 -> 500 for Oligodendrocyte cells
# Processing file #56: H20.33.013_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.013_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1540 -> 500 for Oligodendrocyte cells
# Processing file #57: H21.33.019_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.019_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1520 -> 500 for Oligodendrocyte cells
# Processing file #58: H21.33.036_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.036_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1905 -> 500 for Oligodendrocyte cells
# Processing file #59: H20.33.027_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.027_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 727 -> 500 for Oligodendrocyte cells
# Processing file #60: H20.33.008_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.008_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 582 -> 500 for Oligodendrocyte cells
# Processing file #61: H21.33.002_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.002_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 792 -> 500 for Oligodendrocyte cells
# Processing file #62: H20.33.004_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.004_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 852 -> 500 for Oligodendrocyte cells
# Processing file #63: H21.33.021_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.021_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 329 -> 164 for Oligodendrocyte cells
# Processing file #64: H21.33.035_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.035_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 719 -> 500 for Oligodendrocyte cells
# Processing file #65: H20.33.041_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.041_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1883 -> 500 for Oligodendrocyte cells
# Processing file #66: H21.33.016_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.016_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1940 -> 500 for Oligodendrocyte cells
# Processing file #67: H20.33.033_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.033_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 219 -> 109 for Oligodendrocyte cells
# Processing file #68: H21.33.047_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.047_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 981 -> 500 for Oligodendrocyte cells
# Processing file #69: H21.33.039_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.039_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1013 -> 500 for Oligodendrocyte cells
# Processing file #70: H20.33.028_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.028_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 394 -> 197 for Oligodendrocyte cells
# Processing file #71: H21.33.022_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.022_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1675 -> 500 for Oligodendrocyte cells
# Processing file #72: H19.33.004_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H19.33.004_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 615 -> 500 for Oligodendrocyte cells
# Processing file #73: H21.33.001_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.001_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 702 -> 500 for Oligodendrocyte cells
# Processing file #74: H20.33.024_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.024_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2922 -> 500 for Oligodendrocyte cells
# Processing file #75: H20.33.011_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.011_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2029 -> 500 for Oligodendrocyte cells
# Processing file #76: H21.33.034_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.034_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 29 -> 14 for Oligodendrocyte cells
# Processing file #77: H20.33.040_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.040_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 639 -> 500 for Oligodendrocyte cells
# Processing file #78: H21.33.038_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.038_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1009 -> 500 for Oligodendrocyte cells
# Processing file #79: H20.33.032_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.032_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2112 -> 500 for Oligodendrocyte cells
# Processing file #80: H21.33.046_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.046_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 38 -> 19 for Oligodendrocyte cells
# Processing file #81: H21.33.017_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.017_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 541 -> 500 for Oligodendrocyte cells
# Processing file #82: H21.33.023_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H21.33.023_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 1275 -> 500 for Oligodendrocyte cells
# Processing file #83: H20.33.029_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.029_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 977 -> 500 for Oligodendrocyte cells
# Processing file #84: H20.33.025_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# Successfully deal with H20.33.025_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad: 2376 -> 500 for Oligodendrocyte cells
#
# Start merging...
# Saving the results...
# ALL DONE! Final dimensions of data: (36601, 36646) (genes x cells)
